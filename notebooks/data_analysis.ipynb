# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# ============================================================
# UPLOADING DATASET FILES
# ============================================================
data/processed/calendar_cleaned.csv.gz")
data/processed/reviews_cleaned.csv.gz")
data/processed/listings_cleaned.csv.gz")

# %%
# ============================================================
# JOINING DATASETS
# ============================================================
listing_id
